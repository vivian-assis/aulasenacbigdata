# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/DOMensalEstadoDesde1991.csv', sep= ';')
df = df.loc[(df['ano']>=2014)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ano                         413 non-null    int64
#  1   mes                         413 non-null    int64
#  2   hom_doloso                  413 non-null    int64
#  3   lesao_corp_morte            317 non-null    float64
#  4   latrocinio                  413 non-null    int64
#  5   cvli                        317 non-null    float64
#  6   hom_por_interv_policial     329 non-null    float64
#  7   letalidade_violenta         413 non-null    int64
#  8   tentat_hom                  413 non-null    int64
#  9   lesao_corp_dolosa           413 non-null    int64
#  10  estupro                     269 non-null    float64
#  11  hom_culposo                 329 non-null    float64
#  12  lesao_corp_culposa          317 non-null    float64
#  13  roubo_transeunte            413 non-null    int64
#  14  roubo_celular               305 non-null    float64
#  15  roubo_em_coletivo           413 non-null    int64
#  16  roubo_rua                   413 non-null    int64
#  17  roubo_veiculo               413 non-null    int64
#  18  roubo_carga                 413 non-null    int64
#  19  roubo_comercio              413 non-null    int64
#  20  roubo_residencia            413 non-null    int64
#  21  roubo_banco                 413 non-null    int64
#  22  roubo_cx_eletronico         269 non-null    float64
#  23  roubo_conducao_saque        269 non-null    float64
#  24  roubo_apos_saque            269 non-null    float64
#  25  roubo_bicicleta             137 non-null    float64
#  26  outros_roubos               413 non-null    int64
#  27  total_roubos                413 non-null    int64
#  28  furto_veiculos              413 non-null    int64
#  29  furto_transeunte            413 non-null    int64
#  30  furto_coletivo              269 non-null    float64
#  31  furto_celular               269 non-null    float64
#  32  furto_bicicleta             137 non-null    float64
#  33  outros_furtos               413 non-null    int64
#  34  total_furtos                413 non-null    int64
#  35  sequestro                   317 non-null    float64
#  36  extorsao                    269 non-null    float64
#  37  sequestro_relampago         269 non-null    float64
#  38  estelionato                 269 non-null    float64
#  39  apreensao_drogas            413 non-null    int64
#  40  posse_drogas                233 non-null    float64
#  41  trafico_drogas              233 non-null    float64
#  42  apreensao_drogas_sem_autor  233 non-null    float64
#  43  recuperacao_veiculos        413 non-null    int64
#  44  apf                         233 non-null    float64
#  45  aaapai                      233 non-null    float64
#  46  cmp                         233 non-null    float64
#  47  cmba                        233 non-null    float64
#  48  ameaca                      317 non-null    float64
#  49  pessoas_desaparecidas       281 non-null    float64
#  50  encontro_cadaver            413 non-null    int64
#  51  encontro_ossada             281 non-null    float64
#  52  pol_militares_mortos_serv   269 non-null    float64
#  53  pol_civis_mortos_serv       269 non-null    float64
#  54  registro_ocorrencias        317 non-null    float64
#  55  fase                        413 non-null    int64
# dtypes: float64(31), int64(25)
# memory usage: 180.8 KB

# %%
df_recuperacao = df.groupby(['ano'])['recuperacao_veiculos'].sum().reset_index()
df_roubo_veic = df.groupby(['ano'])['roubo_veiculo'].sum().reset_index()
df_furto_veic = df.groupby(['ano'])['furto_veiculos'].sum().reset_index()

# %%
#df_rec = df_recuperacao.loc[(df_recuperacao['ano']>=2014)]
#df_rec = df_recuperacao.loc[(df_recuperacao['ano']>=2014)]
#df_rec = df_recuperacao.loc[(df_recuperacao['ano']>=2014)]

# %%
df_rec['ano']=df_rec['ano'].astype(str)

# %%
array_rec = np.array(df_rec['recuperacao_veiculos'])

# %%
media_rec = np.mean(array_rec)
media_rec
# Out:
# np.float64(21877.583333333332)

# %%
mediana_rec = np.median(array_rec)
mediana_rec
# Out:
# np.float64(21348.5)

# %%
distancia = (media_rec - mediana_rec)/mediana_rec
distancia
# Out:
# np.float64(0.024783161970786338)

# %%
plt.figure(figsize=(10,5))
plt.plot(df_rec['ano'], df_rec['recuperacao_veiculos'], marker='o', linestyle='-')
plt.title('COMPORTAMENTO DA RECUPERAÇÃO DE VEÍCULOS NA ÚLTIMA DÉCADA')
plt.xlabel('Ano')
plt.ylabel('Veículos Recuperados')
#plt.grid(True) #Não é recomendado utilizar Grids para visualizaçõa de dados
plt.tight_layout()
plt.show()

# %%
print(f"MÉDIA = {media_rec:.2f}\nMEDIANA = {mediana_rec:.2f}\nDISTÂNCIA = {distancia:.2f}")
# Out:
# MÉDIA = 21877.58
# MEDIANA = 21348.50
# DISTÂNCIA = 0.02

# %%
plt.figure(figsize=(10,5))
plt.scatter(df_roubo_veic['roubo_veiculo'],df_recuperacao['recuperacao_veiculos'])
plt.title('Roubos x Recuperação nos últimos 10 anos')
plt.xlabel('Roubo de Veículos')
plt.ylabel('Recuperação de Veículos roubados')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(df_furto_veic['furto_veiculos'],df_recuperacao['recuperacao_veiculos'])
plt.title('Furtos x Recuperação nos últimos 10 anos')
plt.xlabel('Furto de Veículos')
plt.ylabel('Recuperação de Veículos furtados')
plt.show()
